# %%
import rclpy
from rclpy.node import Node

from geometry_msgs.msg import PointStamped
from tf2_ros import Buffer, TransformListener
from tf2_geometry_msgs import do_transform_point

from depthai_ros_msgs.msg import TrackDetection2DArray

import math
from geometry_msgs.msg import Vector3

import numpy as np
from rclpy.time import Time


def rclpy_duration_to_float(duration: rclpy.time.Duration) -> float:
    """
    Convert a ros2 duration (seconds/nanoseconds) to a float.

    Args:
        time: time to convert

    Return:
        time (seconds) as a float
    """
    return float(duration.nanoseconds) / 1e9

# %%
class PersonEKF:

    def __init__(self):
        self.x = np.zeros((4,1))  # [x, y, vx, vy]
        self.P = np.eye(4) * 1.0

        # self.Q = np.eye(4) * 0.05   # process noise
        self.Q = np.eye(4) * 0.5   # process noise
        self.R = np.eye(2) * 0.1    # measurement noise

    def predict(self, dt):

        F = np.array([
            [1, 0, dt, 0],
            [0, 1, 0, dt],
            [0, 0, 1,  0],
            [0, 0, 0,  1]
        ])

        self.x = F @ self.x
        self.P = F @ self.P @ F.T + self.Q

    def update(self, z):

        H = np.array([
            [1,0,0,0],
            [0,1,0,0]
        ])

        y = z - H @ self.x
        S = H @ self.P @ H.T + self.R
        K = self.P @ H.T @ np.linalg.inv(S)

        self.x = self.x + K @ y
        I = np.eye(4)
        self.P = (I - K @ H) @ self.P

# %% [markdown]
# Using:
#
# Topic: /human_relative
#
# Message type: geometry_msgs/msg/Vector3
#
# Vector3.x → distance
# Vector3.y → steering angle (rad)
# Vector3.z → unused (0.0)

# %%
class TrackToMapPoint(Node):

    def __init__(self):
        super().__init__('track_to_map_point')
        # TF buffer & listener
        self.tf_buffer = Buffer()
        self.tf_listener = TransformListener(self.tf_buffer, self)

        self.subscription = self.create_subscription(
            TrackDetection2DArray,
            '/track_detections',
            self.track_callback,
            10
        )

        self.publisher = self.create_publisher(
            PointStamped,
            '/human_position_map',
            10
        )
        
        self.human_pub = self.create_publisher(
            Vector3,
            '/human_relative',
            1
        )

        self.ekf = PersonEKF()

        # Call on_timer function every second
        self.timer = self.create_timer(0.5, self.on_timer)
        self.camera_to_map_transform = None
        self.map_to_robot_transform = None

    def on_timer(self):
        # ---- Lookup transform ----
        try:
            self.camera_to_map_transform = self.tf_buffer.lookup_transform(
                'map',
                'oakd_rgb_camera_optical_frame',
                rclpy.time.Time(),
                timeout=rclpy.duration.Duration(seconds=5.)
            )
        except Exception as ex:
            print("self.camera_to_map_transform", self.camera_to_map_transform)
            self.get_logger().warn(
                f'TF transform failed: {str(ex)}'
            )

        try:
            self.map_to_robot_transform = self.tf_buffer.lookup_transform(
                'base_link',        # target (robot)
                'map',              # source
                rclpy.time.Time(),
                timeout=rclpy.duration.Duration(seconds=0.2)
            )
        except Exception as ex:
            print("self.map_to_robot_transform", self.map_to_robot_transform)
            self.get_logger().warn(
                f'TF transform failed: {str(ex)}'
            )

    def apply_ekf_point(self, current_point):
        z = np.array([
            [current_point.point.x],
            [current_point.point.y]
        ])

        dt = 0.1
        self.ekf.predict(dt)
        self.ekf.update(z)

        # print("EKF result: ", self.ekf.x)
        test = current_point
        test.point.x = self.ekf.x[0][0]
        test.point.y = self.ekf.x[1][0]

        return test

    def track_callback(self, msg: TrackDetection2DArray):
        if self.camera_to_map_transform is None:
            return

        time1 = Time.from_msg(msg.header.stamp)
        time2 = Time.from_msg(self.map_to_robot_transform.header.stamp)

        diff_time = rclpy_duration_to_float(time1 - time2)
        if diff_time > 0.5:
            return
            
        print("\n\n ################## ")
        print("Track header:", time1)
        print("Transform header:", time2)
        print("Time difference: ", time1 > time2, rclpy_duration_to_float(time1 - time2))
        
        point_map = None
        for detection in msg.detections:
            tracking_id = detection.tracking_id
            if tracking_id != "0":
                continue
            
            for track in detection.results:              
                # ---- Create PointStamped in robot frame ----
                point_robot = PointStamped()
                point_robot.header.stamp = msg.header.stamp
                point_robot.header.frame_id = "oakd_rgb_camera_optical_frame" #  self.target_frame
    
                # ADAPT FIELD NAMES TO YOUR MESSAGE
                point_robot.point.x = track.pose.pose.position.x
                point_robot.point.y = track.pose.pose.position.y
                point_robot.point.z = track.pose.pose.position.z

                try:
                    # ---- Transform point ----
                    point_map = do_transform_point(point_robot, self.camera_to_map_transform)

                    ekf_point_map = self.apply_ekf_point(point_map)
                    ekf_point_map.header.frame_id = "map"
    
                    self.publisher.publish(ekf_point_map)

                except Exception as ex:
                    print("self.camera_to_map_transform", self.camera_to_map_transform)
                    self.get_logger().warn(
                        f'TF transform failed: {str(ex)}'
                    )

                # Transform human point into robot frame
                human_robot = do_transform_point(ekf_point_map, self.map_to_robot_transform)
        
                x = human_robot.point.x
                y = human_robot.point.y
        
                distance = math.sqrt(x*x + y*y)
                angle = math.atan2(y, x)   # LEFT positive
        
                out = Vector3()
                out.x = distance
                out.y = angle
                out.z = 0.0
        
                self.human_pub.publish(out)
        
                # # Transform human point into robot frame       
                # x = track.pose.pose.position.z
                # y = track.pose.pose.position.x
        
                # distance = math.sqrt(x*x + y*y)
                # # angle = math.atan2(y, x)   # LEFT positive

                # angle = np.arctan(x / (y + 1e-5))
        
                # out = Vector3()
                # out.x = distance
                # out.y = angle
                # out.z = 0.0
        
                # self.human_pub.publish(out)

        if point_map is None:
            return

# %%
rclpy.init()

node = TrackToMapPoint()
rclpy.spin(node)

node.destroy_node()
rclpy.shutdown()
# Out:
# self.camera_to_map_transform None
# [WARN] [1771833516.136612106] [track_to_map_point]: TF transform failed: Lookup would require extrapolation into the past.  Requested time 1771833511.010750 but the earliest data is at time 1771833511.429832, when looking up transform from frame [oakd_rgb_camera_optical_frame] to frame [map]
# self.map_to_robot_transform None
# [WARN] [1771833516.346206738] [track_to_map_point]: TF transform failed: Lookup would require extrapolation into the past.  Requested time 1771833511.010750 but the earliest data is at time 1771833511.429832, when looking up transform from frame [map] to frame [base_link]
# self.camera_to_map_transform None
# [WARN] [1771833521.360137645] [track_to_map_point]: TF transform failed: Lookup would require extrapolation into the past.  Requested time 1771833511.010750 but the earliest data is at time 1771833511.429832, when looking up transform from frame [oakd_rgb_camera_optical_frame] to frame [map]
# self.map_to_robot_transform None
# [WARN] [1771833521.574222276] [track_to_map_point]: TF transform failed: Lookup would require extrapolation into the past.  Requested time 1771833511.010750 but the earliest data is at time 1771833511.429832, when looking up transform from frame [map] to frame [base_link]
# self.camera_to_map_transform None
# [WARN] [1771833526.601192500] [track_to_map_point]: TF transform failed: Lookup would require extrapolation into the past.  Requested time 1771833511.010750 but the earliest data is at time 1771833511.429832, when looking up transform from frame [oakd_rgb_camera_optical_frame] to frame [map]
# self.map_to_robot_transform None
#
#
#  ##################
# Track header: Time(nanoseconds=1771833525979623437, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833519805532437, clock_type=ROS_TIME)
# Time difference:  True 6.174091
#
#
#  ##################
# Track header: Time(nanoseconds=1771833526079763523, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833519805532437, clock_type=ROS_TIME)
# Time difference:  True 6.274231086
#
#
#  ##################
# Track header: Time(nanoseconds=1771833526178567398, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833519805532437, clock_type=ROS_TIME)
# Time difference:  True 6.373034961
#
#
#  ##################
# Track header: Time(nanoseconds=1771833526278553689, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833519805532437, clock_type=ROS_TIME)
# Time difference:  True 6.473021252
#
#
#  ##################
# Track header: Time(nanoseconds=1771833526378607960, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833519805532437, clock_type=ROS_TIME)
# Time difference:  True 6.573075523
#
#
#  ##################
# Track header: Time(nanoseconds=1771833526479974701, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833519805532437, clock_type=ROS_TIME)
# Time difference:  True 6.674442264
#
#
#  ##################
# Track header: Time(nanoseconds=1771833526580191193, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833519805532437, clock_type=ROS_TIME)
# Time difference:  True 6.774658756
#
#
#  ##################
# Track header: Time(nanoseconds=1771833526677925819, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833519805532437, clock_type=ROS_TIME)
# Time difference:  True 6.872393382
#
#
#  ##################
# Track header: Time(nanoseconds=1771833526780104237, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833519805532437, clock_type=ROS_TIME)
# Time difference:  True 6.9745718
#
#
#  ##################
# Track header: Time(nanoseconds=1771833526878383192, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833519805532437, clock_type=ROS_TIME)
# Time difference:  True 7.072850755
#
#
#  ##################
# Track header: Time(nanoseconds=1771833526978559332, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833519805532437, clock_type=ROS_TIME)
# Time difference:  True 7.173026895
# [WARN] [1771833526.817536947] [track_to_map_point]: TF transform failed: Lookup would require extrapolation into the past.  Requested time 1771833511.010750 but the earliest data is at time 1771833511.429832, when looking up transform from frame [map] to frame [base_link]
#  ##################
# Track header: Time(nanoseconds=1771833527078581141, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833527011762287, clock_type=ROS_TIME)
# Time difference:  True 0.066818854
#
#
#  ##################
# Track header: Time(nanoseconds=1771833527178508025, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833527011762287, clock_type=ROS_TIME)
# Time difference:  True 0.166745738
#
#
#  ##################
# Track header: Time(nanoseconds=1771833527278564592, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833527011762287, clock_type=ROS_TIME)
# Time difference:  True 0.266802305
#
#
#  ##################
# Track header: Time(nanoseconds=1771833527378677030, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833527011762287, clock_type=ROS_TIME)
# Time difference:  True 0.366914743
#
#
#  ##################
# Track header: Time(nanoseconds=1771833527479746829, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833527011762287, clock_type=ROS_TIME)
# Time difference:  True 0.467984542
#
#
#  ##################
# Track header: Time(nanoseconds=1771833527578402372, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833527507774121, clock_type=ROS_TIME)
# Time difference:  True 0.070628251
#
#
#  ##################
# Track header: Time(nanoseconds=1771833527680563106, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833527507774121, clock_type=ROS_TIME)
# Time difference:  True 0.172788985
#
#
#  ##################
# Track header: Time(nanoseconds=1771833527779825921, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833527507774121, clock_type=ROS_TIME)
# Time difference:  True 0.2720518
#
#
#  ##################
# Track header: Time(nanoseconds=1771833527878624130, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833527507774121, clock_type=ROS_TIME)
# Time difference:  True 0.370850009
#
#
#  ##################
# Track header: Time(nanoseconds=1771833527977963575, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833527507774121, clock_type=ROS_TIME)
# Time difference:  True 0.470189454
#
#
#  ##################
# Track header: Time(nanoseconds=1771833528078625026, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833528020020621, clock_type=ROS_TIME)
# Time difference:  True 0.058604405
#
#
#  ##################
# Track header: Time(nanoseconds=1771833528178359004, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833528020020621, clock_type=ROS_TIME)
# Time difference:  True 0.158338383
#
#
#  ##################
# Track header: Time(nanoseconds=1771833528277384470, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833528020020621, clock_type=ROS_TIME)
# Time difference:  True 0.257363849
#
#
#  ##################
# Track header: Time(nanoseconds=1771833528378602471, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833528020020621, clock_type=ROS_TIME)
# Time difference:  True 0.35858185
#
#
#  ##################
# Track header: Time(nanoseconds=1771833528478605039, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833528020020621, clock_type=ROS_TIME)
# Time difference:  True 0.458584418
#
#
#  ##################
# Track header: Time(nanoseconds=1771833528578531701, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833528514774465, clock_type=ROS_TIME)
# Time difference:  True 0.063757236
#
#
#  ##################
# Track header: Time(nanoseconds=1771833528678298216, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833528514774465, clock_type=ROS_TIME)
# Time difference:  True 0.163523751
#
#
#  ##################
# Track header: Time(nanoseconds=1771833528776802261, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833528514774465, clock_type=ROS_TIME)
# Time difference:  True 0.262027796
#
#
#  ##################
# Track header: Time(nanoseconds=1771833528877102511, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833528514774465, clock_type=ROS_TIME)
# Time difference:  True 0.362328046
#
#
#  ##################
# Track header: Time(nanoseconds=1771833528979830554, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833528514774465, clock_type=ROS_TIME)
# Time difference:  True 0.465056089
#
#
#  ##################
# Track header: Time(nanoseconds=1771833529077904770, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833529011796560, clock_type=ROS_TIME)
# Time difference:  True 0.06610821
#
#
#  ##################
# Track header: Time(nanoseconds=1771833529174179558, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833529011796560, clock_type=ROS_TIME)
# Time difference:  True 0.162382998
#
#
#  ##################
# Track header: Time(nanoseconds=1771833529278536622, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833529011796560, clock_type=ROS_TIME)
# Time difference:  True 0.266740062
#
#
#  ##################
# Track header: Time(nanoseconds=1771833529378605412, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833529011796560, clock_type=ROS_TIME)
# Time difference:  True 0.366808852
#
#
#  ##################
# Track header: Time(nanoseconds=1771833529474486037, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833529011796560, clock_type=ROS_TIME)
# Time difference:  True 0.462689477
#
#
#  ##################
# Track header: Time(nanoseconds=1771833529580084757, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833529508363249, clock_type=ROS_TIME)
# Time difference:  True 0.071721508
#
#
#  ##################
# Track header: Time(nanoseconds=1771833529677214555, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833529508363249, clock_type=ROS_TIME)
# Time difference:  True 0.168851306
#
#
#  ##################
# Track header: Time(nanoseconds=1771833529777002255, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833529508363249, clock_type=ROS_TIME)
# Time difference:  True 0.268639006
#
#
#  ##################
# Track header: Time(nanoseconds=1771833529879747409, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833529508363249, clock_type=ROS_TIME)
# Time difference:  True 0.37138416
#
#
#  ##################
# Track header: Time(nanoseconds=1771833529976898133, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833529508363249, clock_type=ROS_TIME)
# Time difference:  True 0.468534884
#
#
#  ##################
# Track header: Time(nanoseconds=1771833530076977071, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833530019762728, clock_type=ROS_TIME)
# Time difference:  True 0.057214343
#
#
#  ##################
# Track header: Time(nanoseconds=1771833530179849353, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833530019762728, clock_type=ROS_TIME)
# Time difference:  True 0.160086625
#
#
#  ##################
# Track header: Time(nanoseconds=1771833530277385944, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833530019762728, clock_type=ROS_TIME)
# Time difference:  True 0.257623216
#
#
#  ##################
# Track header: Time(nanoseconds=1771833530378505909, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833530019762728, clock_type=ROS_TIME)
# Time difference:  True 0.358743181
#
#
#  ##################
# Track header: Time(nanoseconds=1771833530480847307, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833530019762728, clock_type=ROS_TIME)
# Time difference:  True 0.461084579
#
#
#  ##################
# Track header: Time(nanoseconds=1771833530576904116, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833530515790568, clock_type=ROS_TIME)
# Time difference:  True 0.061113548
#
#
#  ##################
# Track header: Time(nanoseconds=1771833530679465883, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833530515790568, clock_type=ROS_TIME)
# Time difference:  True 0.163675315
#
#
#  ##################
# Track header: Time(nanoseconds=1771833530779822633, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833530515790568, clock_type=ROS_TIME)
# Time difference:  True 0.264032065
#
#
#  ##################
# Track header: Time(nanoseconds=1771833530878436158, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833530515790568, clock_type=ROS_TIME)
# Time difference:  True 0.36264559
#
#
#  ##################
# Track header: Time(nanoseconds=1771833530980385393, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833530515790568, clock_type=ROS_TIME)
# Time difference:  True 0.464594825
#
#
#  ##################
# Track header: Time(nanoseconds=1771833531076929864, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833531011766109, clock_type=ROS_TIME)
# Time difference:  True 0.065163755
#
#
#  ##################
# Track header: Time(nanoseconds=1771833531176982098, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833531011766109, clock_type=ROS_TIME)
# Time difference:  True 0.165215989
#
#
#  ##################
# Track header: Time(nanoseconds=1771833531276654003, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833531011766109, clock_type=ROS_TIME)
# Time difference:  True 0.264887894
#
#
#  ##################
# Track header: Time(nanoseconds=1771833531374314408, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833531011766109, clock_type=ROS_TIME)
# Time difference:  True 0.362548299
#
#
#  ##################
# Track header: Time(nanoseconds=1771833531477000358, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833531011766109, clock_type=ROS_TIME)
# Time difference:  True 0.465234249
#
#
#  ##################
# Track header: Time(nanoseconds=1771833531577012760, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833531507780248, clock_type=ROS_TIME)
# Time difference:  True 0.069232512
#
#
#  ##################
# Track header: Time(nanoseconds=1771833531676890477, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833531507780248, clock_type=ROS_TIME)
# Time difference:  True 0.169110229
#
#
#  ##################
# Track header: Time(nanoseconds=1771833531776921286, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833531507780248, clock_type=ROS_TIME)
# Time difference:  True 0.269141038
#
#
#  ##################
# Track header: Time(nanoseconds=1771833531876814262, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833531507780248, clock_type=ROS_TIME)
# Time difference:  True 0.369034014
#
#
#  ##################
# Track header: Time(nanoseconds=1771833531974586055, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833531507780248, clock_type=ROS_TIME)
# Time difference:  True 0.466805807
#
#
#  ##################
# Track header: Time(nanoseconds=1771833532077062396, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833532003839228, clock_type=ROS_TIME)
# Time difference:  True 0.073223168
#
#
#  ##################
# Track header: Time(nanoseconds=1771833532176915484, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833532003839228, clock_type=ROS_TIME)
# Time difference:  True 0.173076256
#
#
#  ##################
# Track header: Time(nanoseconds=1771833532273561454, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833532003839228, clock_type=ROS_TIME)
# Time difference:  True 0.269722226
#
#
#  ##################
# Track header: Time(nanoseconds=1771833532374455532, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833532003839228, clock_type=ROS_TIME)
# Time difference:  True 0.370616304
#
#
#  ##################
# Track header: Time(nanoseconds=1771833532474104733, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833532003839228, clock_type=ROS_TIME)
# Time difference:  True 0.470265505
#
#
#  ##################
# Track header: Time(nanoseconds=1771833532570212967, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833532515780048, clock_type=ROS_TIME)
# Time difference:  True 0.054432919
#
#
#  ##################
# Track header: Time(nanoseconds=1771833532674243535, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833532515780048, clock_type=ROS_TIME)
# Time difference:  True 0.158463487
#
#
#  ##################
# Track header: Time(nanoseconds=1771833532776956485, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833532515780048, clock_type=ROS_TIME)
# Time difference:  True 0.261176437
#
#
#  ##################
# Track header: Time(nanoseconds=1771833532876972239, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833532515780048, clock_type=ROS_TIME)
# Time difference:  True 0.361192191
#
#
#  ##################
# Track header: Time(nanoseconds=1771833532976910067, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833532515780048, clock_type=ROS_TIME)
# Time difference:  True 0.461130019
#
#
#  ##################
# Track header: Time(nanoseconds=1771833533074287085, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833533011797150, clock_type=ROS_TIME)
# Time difference:  True 0.062489935
#
#
#  ##################
# Track header: Time(nanoseconds=1771833533174150432, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833533011797150, clock_type=ROS_TIME)
# Time difference:  True 0.162353282
#
#
#  ##################
# Track header: Time(nanoseconds=1771833533272091686, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833533011797150, clock_type=ROS_TIME)
# Time difference:  True 0.260294536
#
#
#  ##################
# Track header: Time(nanoseconds=1771833533374435288, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833533011797150, clock_type=ROS_TIME)
# Time difference:  True 0.362638138
#
#
#  ##################
# Track header: Time(nanoseconds=1771833533471140239, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833533011797150, clock_type=ROS_TIME)
# Time difference:  True 0.459343089
#
#
#  ##################
# Track header: Time(nanoseconds=1771833533574286963, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833533507787183, clock_type=ROS_TIME)
# Time difference:  True 0.06649978
#
#
#  ##################
# Track header: Time(nanoseconds=1771833533674242587, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833533507787183, clock_type=ROS_TIME)
# Time difference:  True 0.166455404
#
#
#  ##################
# Track header: Time(nanoseconds=1771833533771931454, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833533507787183, clock_type=ROS_TIME)
# Time difference:  True 0.264144271
#
#
#  ##################
# Track header: Time(nanoseconds=1771833533874488851, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833533507787183, clock_type=ROS_TIME)
# Time difference:  True 0.366701668
#
#
#  ##################
# Track header: Time(nanoseconds=1771833533970524567, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833533507787183, clock_type=ROS_TIME)
# Time difference:  True 0.462737384
#
#
#  ##################
# Track header: Time(nanoseconds=1771833534074445765, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833534019766155, clock_type=ROS_TIME)
# Time difference:  True 0.05467961
#
#
#  ##################
# Track header: Time(nanoseconds=1771833534176995717, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833534019766155, clock_type=ROS_TIME)
# Time difference:  True 0.157229562
#
#
#  ##################
# Track header: Time(nanoseconds=1771833534273815092, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833534019766155, clock_type=ROS_TIME)
# Time difference:  True 0.254048937
#
#
#  ##################
# Track header: Time(nanoseconds=1771833534374734059, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833534019766155, clock_type=ROS_TIME)
# Time difference:  True 0.354967904
#
#
#  ##################
# Track header: Time(nanoseconds=1771833534474541407, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833534019766155, clock_type=ROS_TIME)
# Time difference:  True 0.454775252
#
#
#  ##################
# Track header: Time(nanoseconds=1771833534574988879, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833534515778000, clock_type=ROS_TIME)
# Time difference:  True 0.059210879
#
#
#  ##################
# Track header: Time(nanoseconds=1771833534673739032, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833534515778000, clock_type=ROS_TIME)
# Time difference:  True 0.157961032
#
#
#  ##################
# Track header: Time(nanoseconds=1771833534779801026, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833534515778000, clock_type=ROS_TIME)
# Time difference:  True 0.264023026
#
#
#  ##################
# Track header: Time(nanoseconds=1771833534874217924, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833534515778000, clock_type=ROS_TIME)
# Time difference:  True 0.358439924
#
#
#  ##################
# Track header: Time(nanoseconds=1771833534974275047, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833534515778000, clock_type=ROS_TIME)
# Time difference:  True 0.458497047
#
#
#  ##################
# Track header: Time(nanoseconds=1771833535074201541, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833535011791845, clock_type=ROS_TIME)
# Time difference:  True 0.062409696
#
#
#  ##################
# Track header: Time(nanoseconds=1771833535176910547, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833535011791845, clock_type=ROS_TIME)
# Time difference:  True 0.165118702
#
#
#  ##################
# Track header: Time(nanoseconds=1771833535273711960, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833535011791845, clock_type=ROS_TIME)
# Time difference:  True 0.261920115
#
#
#  ##################
# Track header: Time(nanoseconds=1771833535377037479, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833535011791845, clock_type=ROS_TIME)
# Time difference:  True 0.365245634
#
#
#  ##################
# Track header: Time(nanoseconds=1771833535477140101, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833535011791845, clock_type=ROS_TIME)
# Time difference:  True 0.465348256
#
#
#  ##################
# Track header: Time(nanoseconds=1771833535576365362, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833535507911164, clock_type=ROS_TIME)
# Time difference:  True 0.068454198
#
#
#  ##################
# Track header: Time(nanoseconds=1771833535676911314, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833535507911164, clock_type=ROS_TIME)
# Time difference:  True 0.16900015
#
#
#  ##################
# Track header: Time(nanoseconds=1771833535778833846, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833535507911164, clock_type=ROS_TIME)
# Time difference:  True 0.270922682
#
#
#  ##################
# Track header: Time(nanoseconds=1771833535876795137, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833535507911164, clock_type=ROS_TIME)
# Time difference:  True 0.368883973
#
#
#  ##################
# Track header: Time(nanoseconds=1771833535976644169, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833535507911164, clock_type=ROS_TIME)
# Time difference:  True 0.468733005
#
#
#  ##################
# Track header: Time(nanoseconds=1771833536076836365, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833536004024848, clock_type=ROS_TIME)
# Time difference:  True 0.072811517
#
#
#  ##################
# Track header: Time(nanoseconds=1771833536176875711, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833536004024848, clock_type=ROS_TIME)
# Time difference:  True 0.172850863
#
#
#  ##################
# Track header: Time(nanoseconds=1771833536274098749, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833536004024848, clock_type=ROS_TIME)
# Time difference:  True 0.270073901
#
#
#  ##################
# Track header: Time(nanoseconds=1771833536376691849, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833536004024848, clock_type=ROS_TIME)
# Time difference:  True 0.372667001
#
#
#  ##################
# Track header: Time(nanoseconds=1771833536476995877, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833536004024848, clock_type=ROS_TIME)
# Time difference:  True 0.472971029
#
#
#  ##################
# Track header: Time(nanoseconds=1771833536576689541, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833536515793105, clock_type=ROS_TIME)
# Time difference:  True 0.060896436
#
#
#  ##################
# Track header: Time(nanoseconds=1771833536676922681, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833536515793105, clock_type=ROS_TIME)
# Time difference:  True 0.161129576
#
#
#  ##################
# Track header: Time(nanoseconds=1771833536778452531, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833536515793105, clock_type=ROS_TIME)
# Time difference:  True 0.262659426
#
#
#  ##################
# Track header: Time(nanoseconds=1771833536877077408, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833536515793105, clock_type=ROS_TIME)
# Time difference:  True 0.361284303
#
#
#  ##################
# Track header: Time(nanoseconds=1771833536976870071, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833536515793105, clock_type=ROS_TIME)
# Time difference:  True 0.461076966
#
#
#  ##################
# Track header: Time(nanoseconds=1771833537076840602, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833537011845645, clock_type=ROS_TIME)
# Time difference:  True 0.064994957
#
#
#  ##################
# Track header: Time(nanoseconds=1771833537176939984, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833537011845645, clock_type=ROS_TIME)
# Time difference:  True 0.165094339
#
#
#  ##################
# Track header: Time(nanoseconds=1771833537276693536, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833537011845645, clock_type=ROS_TIME)
# Time difference:  True 0.264847891
#
#
#  ##################
# Track header: Time(nanoseconds=1771833537376994638, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833537011845645, clock_type=ROS_TIME)
# Time difference:  True 0.365148993
#
#
#  ##################
# Track header: Time(nanoseconds=1771833537476899800, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833537011845645, clock_type=ROS_TIME)
# Time difference:  True 0.465054155
#
#
#  ##################
# Track header: Time(nanoseconds=1771833537576776758, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833537507804444, clock_type=ROS_TIME)
# Time difference:  True 0.068972314
#
#
#  ##################
# Track header: Time(nanoseconds=1771833537677082750, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833537507804444, clock_type=ROS_TIME)
# Time difference:  True 0.169278306
#
#
#  ##################
# Track header: Time(nanoseconds=1771833537778811765, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833537507804444, clock_type=ROS_TIME)
# Time difference:  True 0.271007321
#
#
#  ##################
# Track header: Time(nanoseconds=1771833537876761259, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833537507804444, clock_type=ROS_TIME)
# Time difference:  True 0.368956815
#
#
#  ##################
# Track header: Time(nanoseconds=1771833537971821540, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833537507804444, clock_type=ROS_TIME)
# Time difference:  True 0.464017096
#
#
#  ##################
# Track header: Time(nanoseconds=1771833538074357659, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833538019804837, clock_type=ROS_TIME)
# Time difference:  True 0.054552822
#
#
#  ##################
# Track header: Time(nanoseconds=1771833538172258302, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833538019804837, clock_type=ROS_TIME)
# Time difference:  True 0.152453465
#
#
#  ##################
# Track header: Time(nanoseconds=1771833538274260629, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833538019804837, clock_type=ROS_TIME)
# Time difference:  True 0.254455792
#
#
#  ##################
# Track header: Time(nanoseconds=1771833538372180365, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833538019804837, clock_type=ROS_TIME)
# Time difference:  True 0.352375528
#
#
#  ##################
# Track header: Time(nanoseconds=1771833538474600596, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833538019804837, clock_type=ROS_TIME)
# Time difference:  True 0.454795759
#
#
#  ##################
# Track header: Time(nanoseconds=1771833538571908393, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833538515786457, clock_type=ROS_TIME)
# Time difference:  True 0.056121936
#
#
#  ##################
# Track header: Time(nanoseconds=1771833538671952127, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833538515786457, clock_type=ROS_TIME)
# Time difference:  True 0.15616567
#
#
#  ##################
# Track header: Time(nanoseconds=1771833538772738614, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833538515786457, clock_type=ROS_TIME)
# Time difference:  True 0.256952157
#
#
#  ##################
# Track header: Time(nanoseconds=1771833538872183669, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833538515786457, clock_type=ROS_TIME)
# Time difference:  True 0.356397212
#
#
#  ##################
# Track header: Time(nanoseconds=1771833538971357726, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833538515786457, clock_type=ROS_TIME)
# Time difference:  True 0.455571269
#
#
#  ##################
# Track header: Time(nanoseconds=1771833539071510626, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833539011782724, clock_type=ROS_TIME)
# Time difference:  True 0.059727902
#
#
#  ##################
# Track header: Time(nanoseconds=1771833539172251909, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833539011782724, clock_type=ROS_TIME)
# Time difference:  True 0.160469185
#
#
#  ##################
# Track header: Time(nanoseconds=1771833539271554354, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833539011782724, clock_type=ROS_TIME)
# Time difference:  True 0.25977163
#
#
#  ##################
# Track header: Time(nanoseconds=1771833539371457127, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833539011782724, clock_type=ROS_TIME)
# Time difference:  True 0.359674403
#
#
#  ##################
# Track header: Time(nanoseconds=1771833539472144967, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833539011782724, clock_type=ROS_TIME)
# Time difference:  True 0.460362243
#
#
#  ##################
# Track header: Time(nanoseconds=1771833539571979518, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833539507791770, clock_type=ROS_TIME)
# Time difference:  True 0.064187748
#
#
#  ##################
# Track header: Time(nanoseconds=1771833539672264546, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833539507791770, clock_type=ROS_TIME)
# Time difference:  True 0.164472776
#
#
#  ##################
# Track header: Time(nanoseconds=1771833539771701731, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833539507791770, clock_type=ROS_TIME)
# Time difference:  True 0.263909961
#
#
#  ##################
# Track header: Time(nanoseconds=1771833539871515949, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833539507791770, clock_type=ROS_TIME)
# Time difference:  True 0.363724179
#
#
#  ##################
# Track header: Time(nanoseconds=1771833539971281779, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833539507791770, clock_type=ROS_TIME)
# Time difference:  True 0.463490009
#
#
#  ##################
# Track header: Time(nanoseconds=1771833540071945378, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833540004300990, clock_type=ROS_TIME)
# Time difference:  True 0.067644388
#
#
#  ##################
# Track header: Time(nanoseconds=1771833540171923224, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833540004300990, clock_type=ROS_TIME)
# Time difference:  True 0.167622234
#
#
#  ##################
# Track header: Time(nanoseconds=1771833540270205419, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833540004300990, clock_type=ROS_TIME)
# Time difference:  True 0.265904429
#
#
#  ##################
# Track header: Time(nanoseconds=1771833540370557817, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833540004300990, clock_type=ROS_TIME)
# Time difference:  True 0.366256827
#
#
#  ##################
# Track header: Time(nanoseconds=1771833540470785328, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833540004300990, clock_type=ROS_TIME)
# Time difference:  True 0.466484338
#
#
#  ##################
# Track header: Time(nanoseconds=1771833540570177272, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833540515864079, clock_type=ROS_TIME)
# Time difference:  True 0.054313193
#
#
#  ##################
# Track header: Time(nanoseconds=1771833540671001184, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833540515864079, clock_type=ROS_TIME)
# Time difference:  True 0.155137105
#
#
#  ##################
# Track header: Time(nanoseconds=1771833540771911762, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833540515864079, clock_type=ROS_TIME)
# Time difference:  True 0.256047683
#
#
#  ##################
# Track header: Time(nanoseconds=1771833540872227420, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833540515864079, clock_type=ROS_TIME)
# Time difference:  True 0.356363341
#
#
#  ##################
# Track header: Time(nanoseconds=1771833540971317515, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833540515864079, clock_type=ROS_TIME)
# Time difference:  True 0.455453436
#
#
#  ##################
# Track header: Time(nanoseconds=1771833541070858365, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833541011795830, clock_type=ROS_TIME)
# Time difference:  True 0.059062535
#
#
#  ##################
# Track header: Time(nanoseconds=1771833541171314411, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833541011795830, clock_type=ROS_TIME)
# Time difference:  True 0.159518581
#
#
#  ##################
# Track header: Time(nanoseconds=1771833541271120777, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833541011795830, clock_type=ROS_TIME)
# Time difference:  True 0.259324947
#
#
#  ##################
# Track header: Time(nanoseconds=1771833541370804274, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833541011795830, clock_type=ROS_TIME)
# Time difference:  True 0.359008444
#
#
#  ##################
# Track header: Time(nanoseconds=1771833541470229718, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833541011795830, clock_type=ROS_TIME)
# Time difference:  True 0.458433888
#
#
#  ##################
# Track header: Time(nanoseconds=1771833541571046167, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833541507909626, clock_type=ROS_TIME)
# Time difference:  True 0.063136541
#
#
#  ##################
# Track header: Time(nanoseconds=1771833541671207234, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833541507909626, clock_type=ROS_TIME)
# Time difference:  True 0.163297608
#
#
#  ##################
# Track header: Time(nanoseconds=1771833541770549475, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833541507909626, clock_type=ROS_TIME)
# Time difference:  True 0.262639849
#
#
#  ##################
# Track header: Time(nanoseconds=1771833541870505747, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833541507909626, clock_type=ROS_TIME)
# Time difference:  True 0.362596121
#
#
#  ##################
# Track header: Time(nanoseconds=1771833541970976478, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833541507909626, clock_type=ROS_TIME)
# Time difference:  True 0.463066852
#
#
#  ##################
# Track header: Time(nanoseconds=1771833542071043971, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833542004795105, clock_type=ROS_TIME)
# Time difference:  True 0.066248866
#
#
#  ##################
# Track header: Time(nanoseconds=1771833542170722228, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833542004795105, clock_type=ROS_TIME)
# Time difference:  True 0.165927123
#
#
#  ##################
# Track header: Time(nanoseconds=1771833542270323985, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833542004795105, clock_type=ROS_TIME)
# Time difference:  True 0.26552888
#
#
#  ##################
# Track header: Time(nanoseconds=1771833542369036602, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833542004795105, clock_type=ROS_TIME)
# Time difference:  True 0.364241497
#
#
#  ##################
# Track header: Time(nanoseconds=1771833542471092429, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833542004795105, clock_type=ROS_TIME)
# Time difference:  True 0.466297324
#
#
#  ##################
# Track header: Time(nanoseconds=1771833542570368707, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833542515797944, clock_type=ROS_TIME)
# Time difference:  True 0.054570763
#
#
#  ##################
# Track header: Time(nanoseconds=1771833542669844688, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833542515797944, clock_type=ROS_TIME)
# Time difference:  True 0.154046744
#
#
#  ##################
# Track header: Time(nanoseconds=1771833542770573193, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833542515797944, clock_type=ROS_TIME)
# Time difference:  True 0.254775249
#
#
#  ##################
# Track header: Time(nanoseconds=1771833542870687112, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833542515797944, clock_type=ROS_TIME)
# Time difference:  True 0.354889168
#
#
#  ##################
# Track header: Time(nanoseconds=1771833542971072066, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833542515797944, clock_type=ROS_TIME)
# Time difference:  True 0.455274122
#
#
#  ##################
# Track header: Time(nanoseconds=1771833543069063171, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833543012789360, clock_type=ROS_TIME)
# Time difference:  True 0.056273811
#
#
#  ##################
# Track header: Time(nanoseconds=1771833543169834602, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833543012789360, clock_type=ROS_TIME)
# Time difference:  True 0.157045242
#
#
#  ##################
# Track header: Time(nanoseconds=1771833543268558923, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833543012789360, clock_type=ROS_TIME)
# Time difference:  True 0.255769563
#
#
#  ##################
# Track header: Time(nanoseconds=1771833543371313984, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833543012789360, clock_type=ROS_TIME)
# Time difference:  True 0.358524624
#
#
#  ##################
# Track header: Time(nanoseconds=1771833543469866955, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833543012789360, clock_type=ROS_TIME)
# Time difference:  True 0.457077595
#
#
#  ##################
# Track header: Time(nanoseconds=1771833543570929365, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833543507898866, clock_type=ROS_TIME)
# Time difference:  True 0.063030499
#
#
#  ##################
# Track header: Time(nanoseconds=1771833543671148820, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833543507898866, clock_type=ROS_TIME)
# Time difference:  True 0.163249954
#
#
#  ##################
# Track header: Time(nanoseconds=1771833543770397691, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833543507898866, clock_type=ROS_TIME)
# Time difference:  True 0.262498825
#
#
#  ##################
# Track header: Time(nanoseconds=1771833543870399167, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833543507898866, clock_type=ROS_TIME)
# Time difference:  True 0.362500301
#
#
#  ##################
# Track header: Time(nanoseconds=1771833543970575456, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833543507898866, clock_type=ROS_TIME)
# Time difference:  True 0.46267659
#
#
#  ##################
# Track header: Time(nanoseconds=1771833544071123296, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833544004270230, clock_type=ROS_TIME)
# Time difference:  True 0.066853066
#
#
#  ##################
# Track header: Time(nanoseconds=1771833544170900237, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833544004270230, clock_type=ROS_TIME)
# Time difference:  True 0.166630007
#
#
#  ##################
# Track header: Time(nanoseconds=1771833544269705668, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833544004270230, clock_type=ROS_TIME)
# Time difference:  True 0.265435438
#
#
#  ##################
# Track header: Time(nanoseconds=1771833544371024761, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833544004270230, clock_type=ROS_TIME)
# Time difference:  True 0.366754531
#
#
#  ##################
# Track header: Time(nanoseconds=1771833544470965163, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833544004270230, clock_type=ROS_TIME)
# Time difference:  True 0.466694933
#
#
#  ##################
# Track header: Time(nanoseconds=1771833544570960083, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833544515797557, clock_type=ROS_TIME)
# Time difference:  True 0.055162526
#
#
#  ##################
# Track header: Time(nanoseconds=1771833544670887671, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833544515797557, clock_type=ROS_TIME)
# Time difference:  True 0.155090114
#
#
#  ##################
# Track header: Time(nanoseconds=1771833544771792175, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833544515797557, clock_type=ROS_TIME)
# Time difference:  True 0.255994618
#
#
#  ##################
# Track header: Time(nanoseconds=1771833544870434644, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833544515797557, clock_type=ROS_TIME)
# Time difference:  True 0.354637087
#
#
#  ##################
# Track header: Time(nanoseconds=1771833544969862218, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833544515797557, clock_type=ROS_TIME)
# Time difference:  True 0.454064661
#
#
#  ##################
# Track header: Time(nanoseconds=1771833545069283458, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833545012799459, clock_type=ROS_TIME)
# Time difference:  True 0.056483999
#
#
#  ##################
# Track header: Time(nanoseconds=1771833545169860947, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833545012799459, clock_type=ROS_TIME)
# Time difference:  True 0.157061488
#
#
#  ##################
# Track header: Time(nanoseconds=1771833545268427195, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833545012799459, clock_type=ROS_TIME)
# Time difference:  True 0.255627736
#
#
#  ##################
# Track header: Time(nanoseconds=1771833545369096294, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833545012799459, clock_type=ROS_TIME)
# Time difference:  True 0.356296835
#
#
#  ##################
# Track header: Time(nanoseconds=1771833545469282731, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833545012799459, clock_type=ROS_TIME)
# Time difference:  True 0.456483272
#
#
#  ##################
# Track header: Time(nanoseconds=1771833545569627166, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833545509323761, clock_type=ROS_TIME)
# Time difference:  True 0.060303405
#
#
#  ##################
# Track header: Time(nanoseconds=1771833545669284237, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833545509323761, clock_type=ROS_TIME)
# Time difference:  True 0.159960476
#
#
#  ##################
# Track header: Time(nanoseconds=1771833545771037845, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833545509323761, clock_type=ROS_TIME)
# Time difference:  True 0.261714084
#
#
#  ##################
# Track header: Time(nanoseconds=1771833545869338651, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833545509323761, clock_type=ROS_TIME)
# Time difference:  True 0.36001489
#
#
#  ##################
# Track header: Time(nanoseconds=1771833545969345608, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833545509323761, clock_type=ROS_TIME)
# Time difference:  True 0.460021847
#
#
#  ##################
# Track header: Time(nanoseconds=1771833546068918013, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833546004797345, clock_type=ROS_TIME)
# Time difference:  True 0.064120668
#
#
#  ##################
# Track header: Time(nanoseconds=1771833546169521335, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833546004797345, clock_type=ROS_TIME)
# Time difference:  True 0.16472399
#
#
#  ##################
# Track header: Time(nanoseconds=1771833546268609856, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833546004797345, clock_type=ROS_TIME)
# Time difference:  True 0.263812511
#
#
#  ##################
# Track header: Time(nanoseconds=1771833546369154290, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833546004797345, clock_type=ROS_TIME)
# Time difference:  True 0.364356945
#
#
#  ##################
# Track header: Time(nanoseconds=1771833546469343060, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833546004797345, clock_type=ROS_TIME)
# Time difference:  True 0.464545715
#
#
#  ##################
# Track header: Time(nanoseconds=1771833546569344017, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833546516798213, clock_type=ROS_TIME)
# Time difference:  True 0.052545804
#
#
#  ##################
# Track header: Time(nanoseconds=1771833546669754266, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833546516798213, clock_type=ROS_TIME)
# Time difference:  True 0.152956053
#
#
#  ##################
# Track header: Time(nanoseconds=1771833546770178719, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833546516798213, clock_type=ROS_TIME)
# Time difference:  True 0.253380506
#
#
#  ##################
# Track header: Time(nanoseconds=1771833546869339555, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833546516798213, clock_type=ROS_TIME)
# Time difference:  True 0.352541342
#
#
#  ##################
# Track header: Time(nanoseconds=1771833546969756434, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833546516798213, clock_type=ROS_TIME)
# Time difference:  True 0.452958221
#
#
#  ##################
# Track header: Time(nanoseconds=1771833547068955509, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833547012818994, clock_type=ROS_TIME)
# Time difference:  True 0.056136515
#
#
#  ##################
# Track header: Time(nanoseconds=1771833547169129039, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833547012818994, clock_type=ROS_TIME)
# Time difference:  True 0.156310045
#
#
#  ##################
# Track header: Time(nanoseconds=1771833547268641463, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833547012818994, clock_type=ROS_TIME)
# Time difference:  True 0.255822469
#
#
#  ##################
# Track header: Time(nanoseconds=1771833547369936131, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833547012818994, clock_type=ROS_TIME)
# Time difference:  True 0.357117137
#
#
#  ##################
# Track header: Time(nanoseconds=1771833547469566036, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833547012818994, clock_type=ROS_TIME)
# Time difference:  True 0.456747042
#
#
#  ##################
# Track header: Time(nanoseconds=1771833547569405976, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833547508934818, clock_type=ROS_TIME)
# Time difference:  True 0.060471158
#
#
#  ##################
# Track header: Time(nanoseconds=1771833547669404803, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833547508934818, clock_type=ROS_TIME)
# Time difference:  True 0.160469985
#
#
#  ##################
# Track header: Time(nanoseconds=1771833547769992903, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833547508934818, clock_type=ROS_TIME)
# Time difference:  True 0.261058085
#
#
#  ##################
# Track header: Time(nanoseconds=1771833547868839870, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833547508934818, clock_type=ROS_TIME)
# Time difference:  True 0.359905052
#
#
#  ##################
# Track header: Time(nanoseconds=1771833547968968289, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833547508934818, clock_type=ROS_TIME)
# Time difference:  True 0.460033471
#
#
#  ##################
# Track header: Time(nanoseconds=1771833548069355243, clock_type=ROS_TIME)
# ...
# Track header: Time(nanoseconds=1771833572762641565, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833572517851957, clock_type=ROS_TIME)
# Time difference:  True 0.244789608
#
#
#  ##################
# Track header: Time(nanoseconds=1771833572862712336, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833572517851957, clock_type=ROS_TIME)
# Time difference:  True 0.344860379
#
#
#  ##################
# Track header: Time(nanoseconds=1771833572961151641, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833572517851957, clock_type=ROS_TIME)
# Time difference:  True 0.443299684
#
#
#  ##################
# Track header: Time(nanoseconds=1771833573061365633, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833573013839311, clock_type=ROS_TIME)
# Time difference:  True 0.047526322
#
#
#  ##################
# Track header: Time(nanoseconds=1771833573161116815, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833573013839311, clock_type=ROS_TIME)
# Time difference:  True 0.147277504
#
#
#  ##################
# Track header: Time(nanoseconds=1771833573261228993, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833573013839311, clock_type=ROS_TIME)
# Time difference:  True 0.247389682
#
#
#  ##################
# Track header: Time(nanoseconds=1771833573360963563, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833573013839311, clock_type=ROS_TIME)
# Time difference:  True 0.347124252
#
#
#  ##################
# Track header: Time(nanoseconds=1771833573461469294, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833573013839311, clock_type=ROS_TIME)
# Time difference:  True 0.447629983
#
#
#  ##################
# Track header: Time(nanoseconds=1771833573561126309, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833573510154878, clock_type=ROS_TIME)
# Time difference:  True 0.050971431
#
#
#  ##################
# Track header: Time(nanoseconds=1771833573660907787, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833573510154878, clock_type=ROS_TIME)
# Time difference:  True 0.150752909
#
#
#  ##################
# Track header: Time(nanoseconds=1771833573760539599, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833573510154878, clock_type=ROS_TIME)
# Time difference:  True 0.250384721
#
#
#  ##################
# Track header: Time(nanoseconds=1771833573861428029, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833573510154878, clock_type=ROS_TIME)
# Time difference:  True 0.351273151
#
#
#  ##################
# Track header: Time(nanoseconds=1771833573961058471, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833573510154878, clock_type=ROS_TIME)
# Time difference:  True 0.450903593
#
#
#  ##################
# Track header: Time(nanoseconds=1771833574061469665, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833574006058140, clock_type=ROS_TIME)
# Time difference:  True 0.055411525
#
#
#  ##################
# Track header: Time(nanoseconds=1771833574161250865, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833574006058140, clock_type=ROS_TIME)
# Time difference:  True 0.155192725
#
#
#  ##################
# Track header: Time(nanoseconds=1771833574261318822, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833574006058140, clock_type=ROS_TIME)
# Time difference:  True 0.255260682
#
#
#  ##################
# Track header: Time(nanoseconds=1771833574360125919, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833574006058140, clock_type=ROS_TIME)
# Time difference:  True 0.354067779
#
#
#  ##################
# Track header: Time(nanoseconds=1771833574460147987, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833574006058140, clock_type=ROS_TIME)
# Time difference:  True 0.454089847
#
#
#  ##################
# Track header: Time(nanoseconds=1771833574561453654, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833574517907105, clock_type=ROS_TIME)
# Time difference:  True 0.043546549
#
#
#  ##################
# Track header: Time(nanoseconds=1771833574659162577, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833574517907105, clock_type=ROS_TIME)
# Time difference:  True 0.141255472
#
#
#  ##################
# Track header: Time(nanoseconds=1771833574760102526, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833574517907105, clock_type=ROS_TIME)
# Time difference:  True 0.242195421
#
#
#  ##################
# Track header: Time(nanoseconds=1771833574861517932, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833574517907105, clock_type=ROS_TIME)
# Time difference:  True 0.343610827
#
#
#  ##################
# Track header: Time(nanoseconds=1771833574960235772, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833574517907105, clock_type=ROS_TIME)
# Time difference:  True 0.442328667
#
#
#  ##################
# Track header: Time(nanoseconds=1771833575059674512, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833575013832629, clock_type=ROS_TIME)
# Time difference:  True 0.045841883
#
#
#  ##################
# Track header: Time(nanoseconds=1771833575159613951, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833575013832629, clock_type=ROS_TIME)
# Time difference:  True 0.145781322
#
#
#  ##################
# Track header: Time(nanoseconds=1771833575259787999, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833575013832629, clock_type=ROS_TIME)
# Time difference:  True 0.24595537
#
#
#  ##################
# Track header: Time(nanoseconds=1771833575360743206, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833575013832629, clock_type=ROS_TIME)
# Time difference:  True 0.346910577
#
#
#  ##################
# Track header: Time(nanoseconds=1771833575459983837, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833575013832629, clock_type=ROS_TIME)
# Time difference:  True 0.446151208
#
#
#  ##################
# Track header: Time(nanoseconds=1771833575560384031, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833575509829249, clock_type=ROS_TIME)
# Time difference:  True 0.050554782
#
#
#  ##################
# Track header: Time(nanoseconds=1771833575660214360, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833575509829249, clock_type=ROS_TIME)
# Time difference:  True 0.150385111
#
#
#  ##################
# Track header: Time(nanoseconds=1771833575760751405, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833575509829249, clock_type=ROS_TIME)
# Time difference:  True 0.250922156
#
#
#  ##################
# Track header: Time(nanoseconds=1771833575859846222, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833575509829249, clock_type=ROS_TIME)
# Time difference:  True 0.350016973
#
#
#  ##################
# Track header: Time(nanoseconds=1771833575959620996, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833575509829249, clock_type=ROS_TIME)
# Time difference:  True 0.449791747
#
#
#  ##################
# Track header: Time(nanoseconds=1771833576059731730, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833576006411881, clock_type=ROS_TIME)
# Time difference:  True 0.053319849
#
#
#  ##################
# Track header: Time(nanoseconds=1771833576158992786, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833576006411881, clock_type=ROS_TIME)
# Time difference:  True 0.152580905
#
#
#  ##################
# Track header: Time(nanoseconds=1771833576259997938, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833576006411881, clock_type=ROS_TIME)
# Time difference:  True 0.253586057
#
#
#  ##################
# Track header: Time(nanoseconds=1771833576359724175, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833576006411881, clock_type=ROS_TIME)
# Time difference:  True 0.353312294
#
#
#  ##################
# Track header: Time(nanoseconds=1771833576460037518, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833576006411881, clock_type=ROS_TIME)
# Time difference:  True 0.453625637
#
#
#  ##################
# Track header: Time(nanoseconds=1771833576559776255, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833576519863373, clock_type=ROS_TIME)
# Time difference:  True 0.039912882
#
#
#  ##################
# Track header: Time(nanoseconds=1771833576660134616, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833576519863373, clock_type=ROS_TIME)
# Time difference:  True 0.140271243
#
#
#  ##################
# Track header: Time(nanoseconds=1771833576759964649, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833576519863373, clock_type=ROS_TIME)
# Time difference:  True 0.240101276
#
#
#  ##################
# Track header: Time(nanoseconds=1771833576859820885, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833576519863373, clock_type=ROS_TIME)
# Time difference:  True 0.339957512
#
#
#  ##################
# Track header: Time(nanoseconds=1771833576962809981, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833576519863373, clock_type=ROS_TIME)
# Time difference:  True 0.442946608
#
#
#  ##################
# Track header: Time(nanoseconds=1771833577061465562, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833577013847088, clock_type=ROS_TIME)
# Time difference:  True 0.047618474
#
#
#  ##################
# Track header: Time(nanoseconds=1771833577160369659, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833577013847088, clock_type=ROS_TIME)
# Time difference:  True 0.146522571
#
#
#  ##################
# Track header: Time(nanoseconds=1771833577259663659, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833577013847088, clock_type=ROS_TIME)
# Time difference:  True 0.245816571
#
#
#  ##################
# Track header: Time(nanoseconds=1771833577360699903, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833577013847088, clock_type=ROS_TIME)
# Time difference:  True 0.346852815
#
#
#  ##################
# Track header: Time(nanoseconds=1771833577459507038, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833577013847088, clock_type=ROS_TIME)
# Time difference:  True 0.44565995
#
#
#  ##################
# Track header: Time(nanoseconds=1771833577559271627, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833577510160910, clock_type=ROS_TIME)
# Time difference:  True 0.049110717
#
#
#  ##################
# Track header: Time(nanoseconds=1771833577659297658, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833577510160910, clock_type=ROS_TIME)
# Time difference:  True 0.149136748
#
#
#  ##################
# Track header: Time(nanoseconds=1771833577759198467, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833577510160910, clock_type=ROS_TIME)
# Time difference:  True 0.249037557
#
#
#  ##################
# Track header: Time(nanoseconds=1771833577860391987, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833577510160910, clock_type=ROS_TIME)
# Time difference:  True 0.350231077
#
#
#  ##################
# Track header: Time(nanoseconds=1771833577959475046, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833577510160910, clock_type=ROS_TIME)
# Time difference:  True 0.449314136
#
#
#  ##################
# Track header: Time(nanoseconds=1771833578058747472, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833578006036393, clock_type=ROS_TIME)
# Time difference:  True 0.052711079
#
#
#  ##################
# Track header: Time(nanoseconds=1771833578159616199, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833578006036393, clock_type=ROS_TIME)
# Time difference:  True 0.153579806
#
#
#  ##################
# Track header: Time(nanoseconds=1771833578261999912, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833578006036393, clock_type=ROS_TIME)
# Time difference:  True 0.255963519
#
#
#  ##################
# Track header: Time(nanoseconds=1771833578360098924, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833578006036393, clock_type=ROS_TIME)
# Time difference:  True 0.354062531
#
#
#  ##################
# Track header: Time(nanoseconds=1771833578459341832, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833578006036393, clock_type=ROS_TIME)
# Time difference:  True 0.453305439
#
#
#  ##################
# Track header: Time(nanoseconds=1771833578558917682, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833578518062876, clock_type=ROS_TIME)
# Time difference:  True 0.040854806
#
#
#  ##################
# Track header: Time(nanoseconds=1771833578659479782, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833578518062876, clock_type=ROS_TIME)
# Time difference:  True 0.141416906
#
#
#  ##################
# Track header: Time(nanoseconds=1771833578760094363, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833578518062876, clock_type=ROS_TIME)
# Time difference:  True 0.242031487
#
#
#  ##################
# Track header: Time(nanoseconds=1771833578860341021, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833578518062876, clock_type=ROS_TIME)
# Time difference:  True 0.342278145
#
#
#  ##################
# Track header: Time(nanoseconds=1771833578959133416, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833578518062876, clock_type=ROS_TIME)
# Time difference:  True 0.44107054
#
#
#  ##################
# Track header: Time(nanoseconds=1771833579059139169, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833579015831103, clock_type=ROS_TIME)
# Time difference:  True 0.043308066
#
#
#  ##################
# Track header: Time(nanoseconds=1771833579159333994, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833579015831103, clock_type=ROS_TIME)
# Time difference:  True 0.143502891
#
#
#  ##################
# Track header: Time(nanoseconds=1771833579259286952, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833579015831103, clock_type=ROS_TIME)
# Time difference:  True 0.243455849
#
#
#  ##################
# Track header: Time(nanoseconds=1771833579359162817, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833579015831103, clock_type=ROS_TIME)
# Time difference:  True 0.343331714
#
#
#  ##################
# Track header: Time(nanoseconds=1771833579460075303, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833579015831103, clock_type=ROS_TIME)
# Time difference:  True 0.4442442
#
#
#  ##################
# Track header: Time(nanoseconds=1771833579558933974, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833579509834072, clock_type=ROS_TIME)
# Time difference:  True 0.049099902
#
#
#  ##################
# Track header: Time(nanoseconds=1771833579659348668, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833579509834072, clock_type=ROS_TIME)
# Time difference:  True 0.149514596
#
#
#  ##################
# Track header: Time(nanoseconds=1771833579759342459, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833579509834072, clock_type=ROS_TIME)
# Time difference:  True 0.249508387
#
#
#  ##################
# Track header: Time(nanoseconds=1771833579860992530, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833579509834072, clock_type=ROS_TIME)
# Time difference:  True 0.351158458
#
#
#  ##################
# Track header: Time(nanoseconds=1771833579959205615, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833579509834072, clock_type=ROS_TIME)
# Time difference:  True 0.449371543
#
#
#  ##################
# Track header: Time(nanoseconds=1771833580058832353, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833580008214587, clock_type=ROS_TIME)
# Time difference:  True 0.050617766
#
#
#  ##################
# Track header: Time(nanoseconds=1771833580159417083, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833580008214587, clock_type=ROS_TIME)
# Time difference:  True 0.151202496
#
#
#  ##################
# Track header: Time(nanoseconds=1771833580259303930, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833580008214587, clock_type=ROS_TIME)
# Time difference:  True 0.251089343
#
#
#  ##################
# Track header: Time(nanoseconds=1771833580361446589, clock_type=ROS_TIME)
# Transform header: Time(nanoseconds=1771833580008214587, clock_type=ROS_TIME)
# Time difference:  True 0.353232002
